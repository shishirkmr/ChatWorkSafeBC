# %%
# Setup Langsmith

# %%
# !pip install -U langchain
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 810.5/810.5 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 15.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.9/273.9 kB 15.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.8/144.8 kB 11.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.9/262.9 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.5 MB/s eta 0:00:00
# ...

# %%
LANGCHAIN_TRACING_V2=True
LANGCHAIN_ENDPOINT="https://api.smith.langchain.com"
LANGCHAIN_API_KEY="ls__c769d7810b7f4df58f51cec7b45ad45d"
LANGCHAIN_PROJECT="WorkSafeBC"

# %%
from getpass import getpass
OPENAI_API_KEY = getpass("OpenAI API Key: ")
# Out:
# OpenAI API Key: ··········

# %%
import os
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# %%
from langchain.chat_models import ChatOpenAI

llm = ChatOpenAI()
llm.invoke("Hello, world!")
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.chat_models.openai.ChatOpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(
# AIMessage(content='Hello there! How can I assist you today?', response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 11, 'total_tokens': 21}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': 'fp_3bc1b5746c', 'finish_reason': 'stop', 'logprobs': None})

# %% [markdown]
# ## Setup RAGAS Framework for RAG Evaluation

# %%
# Setup RAGAS

# %%
# !pip install ragas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 994.0 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.8 MB/s eta 0:00:00
# ...

# %%
from datasets import Dataset
import os
from ragas import evaluate
from ragas.metrics import faithfulness, answer_correctness

os.environ["OPENAI_API_KEY"] = "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"

data_samples = {
    'question': ['When was the first super bowl?', 'Who won the most super bowls?'],
    'answer': ['The first superbowl was held on Jan 15, 1967', 'The most super bowls have been won by The New England Patriots'],
    'contexts' : [['The First AFL–NFL World Championship Game was an American football game played on January 15, 1967, at the Los Angeles Memorial Coliseum in Los Angeles,'],
    ['The Green Bay Packers...Green Bay, Wisconsin.','The Packers compete...Football Conference']],
    'ground_truth': ['The first superbowl was held on January 15, 1967', 'The New England Patriots have won the Super Bowl a record six times']
}

dataset = Dataset.from_dict(data_samples)

score = evaluate(dataset)
score.to_pandas()
# Out:
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
#                          question  \
# 0  When was the first super bowl?
# 1   Who won the most super bowls?
#
#                                               answer  \
# 0       The first superbowl was held on Jan 15, 1967
# 1  The most super bowls have been won by The New ...
#
#                                             contexts  \
# 0  [The First AFL–NFL World Championship Game was...
# 1  [The Green Bay Packers...Green Bay, Wisconsin....
#
#                                         ground_truth  answer_relevancy  \
# 0   The first superbowl was held on January 15, 1967          0.980736
# 1  The New England Patriots have won the Super Bo...          0.943002
#
#    context_precision  faithfulness  context_recall
# 0                1.0           0.0             1.0
# 1                0.0           0.0             0.0

# %% [markdown]
# # Setup Pinecone

# %%
# !pip install pinecone-client
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.0/214.0 kB 3.9 MB/s eta 0:00:00
# ...

# %%
from getpass import getpass
PINECONE_API_KEY = getpass("Pinecone API Key: ")
# 35e5d7e7-46ac-4f55-9734-f6dc754e6e79
os.environ['PINECONE_API_KEY'] = PINECONE_API_KEY
# Out:
# Pinecone API Key: ··········

# %%
from langchain.embeddings.openai import OpenAIEmbeddings

model_name = 'text-embedding-3-small'

embed = OpenAIEmbeddings(
    model=model_name,
    openai_api_key=OPENAI_API_KEY
)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.embeddings.openai.OpenAIEmbeddings` was deprecated in langchain-community 0.0.9 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(

# %%
from pinecone import Pinecone

PINECONE_ENVIRONMENT = "gcp-starter"

index_name = 'work-safe-bc'
pc = Pinecone(
        api_key=os.environ.get("PINECONE_API_KEY")
    )
if index_name not in pc.list_indexes().names():
    # we create a new index
    pc.create_index(
        name=index_name,
        metric='cosine',
        dimension=3072
    )

# %%
from langchain.vectorstores import Pinecone

text_field = "text"

# switch back to normal index for langchain
index = pc.Index(index_name)

vectorstore = Pinecone(
    index, embed.embed_query, text_field
)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.vectorstores.pinecone.Pinecone` was deprecated in langchain-community 0.0.18 and will be removed in 0.2.0. An updated version of the class exists in the langchain-pinecone package and should be used instead. To use it run `pip install -U langchain-pinecone` and import as `from langchain_pinecone import Pinecone`.
#   warn_deprecated(
# /usr/local/lib/python3.10/dist-packages/langchain_community/vectorstores/pinecone.py:68: UserWarning: Passing in `embedding` as a Callable is deprecated. Please pass in an Embeddings object instead.
#   warnings.warn(

# %%
query = "what was the safety guidelines for bakeries?"

vector_search_results = vectorstore.similarity_search_with_score(
    query,  # our search query
    k=3  # return 10 most relevant docs
)
# vector_search_results
print(vector_search_results)
# Out:
# [(Document(page_content='Avoid spreading the flour by hand. Cleaning up\n\t* Do not use compressed air for cleaning. * Do not dry sweep equipment, tabletops, or floors. * Use a HEPA vacuum to remove flour dust from surfaces. * Use a wet mop to clean floors. * Do not let dust accumulate. Clean up spills immediately. * Place waste in covered waste bins. * Take HEPA vacuums outside before changing bags or filters. * Wear a half-face N95 disposable respirator when emptying the HEPA vacuum or changing the filter. Respirators\n* Each worker will be fit-tested if a respirator is required. * The worker must be clean-shaven where the respirator seals with the face. * Used respirators will be discarded at the end of each shift. * When the worker notices a resistance to breathing, the respirator must be replaced. * Respirators will be used in accordance with the respirator program. Safe work planning\n* Work from the Acceptable Control Methods table included in this exposure control plan. * Ins
# ...

# %%
vector_search_results
# Out:
# [(Document(page_content='Avoid spreading the flour by hand. Cleaning up\n\t* Do not use compressed air for cleaning. * Do not dry sweep equipment, tabletops, or floors. * Use a HEPA vacuum to remove flour dust from surfaces. * Use a wet mop to clean floors. * Do not let dust accumulate. Clean up spills immediately. * Place waste in covered waste bins. * Take HEPA vacuums outside before changing bags or filters. * Wear a half-face N95 disposable respirator when emptying the HEPA vacuum or changing the filter. Respirators\n* Each worker will be fit-tested if a respirator is required. * The worker must be clean-shaven where the respirator seals with the face. * Used respirators will be discarded at the end of each shift. * When the worker notices a resistance to breathing, the respirator must be replaced. * Respirators will be used in accordance with the respirator program. Safe work planning\n* Work from the Acceptable Control Methods table included in this exposure control plan. * Ins
# ...

# %% [markdown]
# ## Generation of Evaluation Pairs

# %%
global_examples = []

# %%
llm_model = 'gpt-3.5-turbo-16k'

# %%
# query = "What are the guidelines relating to the use of resource roads?"
# query = "What are the Obligations relating to the use of resource roads?"
# query =  "What is silica?"
# query =  "What is the purpose of ECP?"
# query =  "How are workers exposed to silica?"
# query =  "What are safe work practices for Barriers and enclosures?"
# query =  "What are the Respiratory protection against silica?"
query =  "What are Safe work procedures?"
# query =  "What is Ventilation safety checklist?"

vector_search_results = vectorstore.similarity_search(
    query,  # our search query
    k=10  # return 10 most relevant docs
)
# vector_search_results
print(vector_search_results)
# Out:
# [Document(page_content='Evidential support for why it is impractical to reroute, de-energize or guard the conductors. A written copy of the work procedures to be used by the workers. A statement regarding the qualifications of the affected workers. A risk assessment showing how the proposed safe work procedures will provide effective protection to workers. A description on how the matter has been discussed with representatives of the workers affected (those who will be doing the work), such as through their representatives on the health and safety committee.', metadata={'chunk_size': 540.0, 'file_name': 'Guidelines.pdf', 'semantic_index': 476.0, 'source': 'https://drive.google.com/file/d/12ZJ_jH8P0DYpYaHz1nNsQMs4I_r1gpJz/view?usp=sharing'}), Document(page_content='Sections 19.24 to 19.28 do not apply to workers who qualify under section 19.29. In order for workers to be under the direct supervision of the qualified workers, the qualified worker must have the authority to direct, limi
# ...

# %%
from langchain.evaluation.qa import QAGenerateChain
example_gen_chain = QAGenerateChain.from_llm(ChatOpenAI(model=llm_model))

# %%
new_examples = example_gen_chain.apply_and_parse(
    [{"doc": t} for t in vector_search_results[:5]]
)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py:344: UserWarning: The apply_and_parse method is deprecated, instead pass an output parser directly to LLMChain.
#   warnings.warn(

# %%
new_examples[0]["qa_pairs"]
# Out:
# {'query': 'What are some of the evidential supports for why it is impractical to reroute, de-energize, or guard the conductors?',
#  'answer': 'Some of the evidential supports for why it is impractical to reroute, de-energize, or guard the conductors include a written copy of the work procedures to be used by the workers, a statement regarding the qualifications of the affected workers, a risk assessment showing how the proposed safe work procedures will provide effective protection to workers, and a description on how the matter has been discussed with representatives of the workers affected, such as through their representatives on the health and safety committee.'}

# %%
new_examples
# Out:
# [{'qa_pairs': {'query': 'What are some of the evidential supports for why it is impractical to reroute, de-energize, or guard the conductors?',
#    'answer': 'Some of the evidential supports for why it is impractical to reroute, de-energize, or guard the conductors include a written copy of the work procedures to be used by the workers, a statement regarding the qualifications of the affected workers, a risk assessment showing how the proposed safe work procedures will provide effective protection to workers, and a description on how the matter has been discussed with representatives of the workers affected, such as through their representatives on the health and safety committee.'}},
#  {'qa_pairs': {'query': 'Which workers are exempt from the provisions of sections 19.24 to 19.28?',
#    'answer': 'Workers who qualify under section 19.29 are exempt from the provisions of sections 19.24 to 19.28.'}},
# ...

# %%
examples = [example["qa_pairs"] for example in new_examples]

# %%
examples
# Out:
# [{'query': 'What are some of the evidential supports for why it is impractical to reroute, de-energize, or guard the conductors?',
#   'answer': 'Some of the evidential supports for why it is impractical to reroute, de-energize, or guard the conductors include a written copy of the work procedures to be used by the workers, a statement regarding the qualifications of the affected workers, a risk assessment showing how the proposed safe work procedures will provide effective protection to workers, and a description on how the matter has been discussed with representatives of the workers affected, such as through their representatives on the health and safety committee.'},
#  {'query': 'Which workers are exempt from the provisions of sections 19.24 to 19.28?',
#   'answer': 'Workers who qualify under section 19.29 are exempt from the provisions of sections 19.24 to 19.28.'},
# ...

# %%
global_examples.extend(examples)

# %%
len(global_examples)
# Out:
# 5

# %%
global_examples
# Out:
# [{'query': 'What are some of the evidential supports for why it is impractical to reroute, de-energize, or guard the conductors?',
#   'answer': 'Some of the evidential supports for why it is impractical to reroute, de-energize, or guard the conductors include a written copy of the work procedures to be used by the workers, a statement regarding the qualifications of the affected workers, a risk assessment showing how the proposed safe work procedures will provide effective protection to workers, and a description on how the matter has been discussed with representatives of the workers affected, such as through their representatives on the health and safety committee.'},
#  {'query': 'Which workers are exempt from the provisions of sections 19.24 to 19.28?',
#   'answer': 'Workers who qualify under section 19.29 are exempt from the provisions of sections 19.24 to 19.28.'},
# ...

# %%
# Manual Steps to Shortlist right/valid set of Question Answer Pairs

# %%
# We can explore to automate this process with LLM calls to classify if the question are valid.

# %%
# Then We evaluate the RAG results from RAGAS farmerwork.

# %%
# score.to_pandas()
